# %%
# import numpy, pyplot and pandas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load predicted data by fits only to sigma(gamma gamma -> X) data
sigmaGammaGamma_pred_PHOJET_data_only = pd.read_csv("SigmaGammaGamma_pred_PHOJET_data_only.txt", sep = '\t')
sigmaGammaGamma_pred_PHYTIA_data_only = pd.read_csv("SigmaGammaGamma_pred_PHYTIA_data_only.txt", sep = '\t')
sigmaGammaGamma_pred_Processed_data_only = pd.read_csv("SigmaGammaGamma_pred_Processed_data_only.txt", sep = '\t')
# Load predicted data coming from joint fits
sigmaGammaGamma_pred_PHOJET = pd.read_csv("SigmaGammaGamma_pred_PHOJET.txt", sep = '\t')
sigmaGammaGamma_pred_PHYTIA = pd.read_csv("SigmaGammaGamma_pred_PHYTIA.txt", sep = '\t')
sigmaGammaGamma_pred_Processed = pd.read_csv("SigmaGammaGamma_pred_Processed.txt", sep = '\t')
# Load exp data
exp_data_PHOJET = pd.read_csv("gammagammaScatteringL3PHOJET.txt", sep = '\t')
exp_data_PHYTIA = pd.read_csv("gammagammaScatteringL3PHYTIA.txt", sep = '\t')
exp_data_Processed = pd.read_csv("gammagammaScatteringL3Processed.txt", sep = '\t')

# %%
# Plots with PHOJET unfolding
plt.errorbar(exp_data_PHOJET["W(GeV)"], exp_data_PHOJET["sigma(nb)"], xerr = [exp_data_PHOJET["WErrorm"],exp_data_PHOJET["WErrorp"]], 
             yerr = [exp_data_PHOJET["Errorm"],exp_data_PHOJET["Errorp"]], fmt = "o", label = "exp. data")
plt.plot(sigmaGammaGamma_pred_PHOJET["W"], sigmaGammaGamma_pred_PHOJET["Pred"], label = "Hard Pomeron")
plt.ylabel(r'$\sigma(nb)$')
plt.xlabel(r'$\sqrt{s}(GeV)$')
plt.xscale("log")
plt.title(r'$\sigma$'+" vs " + r'$\sqrt{s}$')
plt.legend()
plt.ylim(300, 900)
plt.savefig("SigmaGammaGamma_vs_W_PHOJET.pdf")
plt.show()

# %%
# Plots with PHYTIA unfolding
plt.errorbar(exp_data_PHYTIA["W(GeV)"], exp_data_PHYTIA["sigma(nb)"], xerr = [exp_data_PHYTIA["WErrorm"], exp_data_PHYTIA["WErrorp"]], 
             yerr = [exp_data_PHYTIA["Errorm"],exp_data_PHYTIA["Errorp"]], fmt = "o", label = "exp. data")
plt.plot(sigmaGammaGamma_pred_PHYTIA["W"], sigmaGammaGamma_pred_PHYTIA["Pred"], label = "Hard Pomeron")
plt.ylabel(r'$\sigma(nb)$')
plt.xlabel(r'$\sqrt{s}(GeV)$')
plt.xscale("log")
plt.title(r'$\sigma$'+" vs " + r'$\sqrt{s}$')
plt.legend()
plt.ylim(300, 1250)
plt.savefig("SigmaGammaGamma_vs_W_PHYTIA.pdf")
plt.show()

# %%
# Plots with average results
plt.errorbar(exp_data_Processed["W(GeV)"], exp_data_Processed["sigma(nb)"], xerr = [exp_data_Processed["WErrorm"], exp_data_Processed["WErrorp"]], 
             yerr = [exp_data_Processed["Errorm"], exp_data_Processed["Errorp"]], fmt = "o", label = "exp. data")
plt.plot(sigmaGammaGamma_pred_Processed["W"], sigmaGammaGamma_pred_Processed["Pred"], label = "Hard Pomeron")
plt.ylabel(r'$\sigma(nb)$')
plt.xlabel(r'$\sqrt{s}(GeV)$')
plt.xscale("log")
plt.title(r'$\sigma$'+" vs " + r'$\sqrt{s}$')
plt.legend()
plt.ylim(300, 1000)
plt.savefig("SigmaGammaGamma_vs_W_Processed.pdf")
plt.show()

# %%
# Plot fit results with PHOJET unfolding data only
plt.errorbar(exp_data_PHOJET["W(GeV)"], exp_data_PHOJET["sigma(nb)"], xerr = [exp_data_PHOJET["WErrorm"],exp_data_PHOJET["WErrorp"]], 
             yerr = [exp_data_PHOJET["Errorm"],exp_data_PHOJET["Errorp"]], fmt = "o", label = "exp. data")
plt.plot(sigmaGammaGamma_pred_PHOJET_data_only["W"], sigmaGammaGamma_pred_PHOJET_data_only["Pred"], label = "Hard Pomeron")
plt.ylabel(r'$\sigma(nb)$')
plt.xlabel(r'$\sqrt{s}(GeV)$')
plt.xscale("log")
plt.title(r'$\sigma$'+" vs " + r'$\sqrt{s}$')
plt.legend()
plt.ylim(300, 900)
plt.savefig("SigmaGammaGamma_vs_W_PHOJET_data_only.pdf")
plt.show()

# %%
# Plot fit results with PHYTIA unfolding data only
plt.errorbar(exp_data_PHYTIA["W(GeV)"], exp_data_PHYTIA["sigma(nb)"], xerr = [exp_data_PHYTIA["WErrorm"],exp_data_PHYTIA["WErrorp"]], 
             yerr = [exp_data_PHYTIA["Errorm"],exp_data_PHYTIA["Errorp"]], fmt = "o", label = "exp. data")
plt.plot(sigmaGammaGamma_pred_PHYTIA_data_only["W"], sigmaGammaGamma_pred_PHYTIA_data_only["Pred"], label = "Hard Pomeron")
plt.ylabel(r'$\sigma(nb)$')
plt.xlabel(r'$\sqrt{s}(GeV)$')
plt.xscale("log")
plt.title(r'$\sigma$'+" vs " + r'$\sqrt{s}$')
plt.legend()
plt.ylim(300, 1200)
plt.savefig("SigmaGammaGamma_vs_W_PHYTIA_data_only.pdf")
plt.show()

# %%
# Plot fit results with average unfolding data only
plt.errorbar(exp_data_Processed["W(GeV)"], exp_data_Processed["sigma(nb)"], xerr = [exp_data_Processed["WErrorm"],exp_data_Processed["WErrorp"]], 
             yerr = [exp_data_Processed["Errorm"],exp_data_Processed["Errorp"]], fmt = "o", label = "exp. data")
plt.plot(sigmaGammaGamma_pred_Processed_data_only["W"], sigmaGammaGamma_pred_Processed_data_only["Pred"], label = "Hard Pomeron")
plt.ylabel(r'$\sigma(nb)$')
plt.xlabel(r'$\sqrt{s}(GeV)$')
plt.xscale("log")
plt.title(r'$\sigma$'+" vs " + r'$\sqrt{s}$')
plt.legend()
plt.ylim(300, 1200)
plt.savefig("SigmaGammaGamma_vs_W_Processed_data_only.pdf")
plt.show()
